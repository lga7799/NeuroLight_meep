# %%
import sys
import collections
collections.Iterable = collections.abc.Iterable
import matplotlib.pylab as plt
import numpy as np
import meep as mp

# %%
n = 3.4 #index of waveguide
w = 1 # width of waveguide
r = 2.2 # inner radius of ring
pad = 4 # padding between waveguide and edge of PML
dpml = 2 # thickness of PML
sxy = 2*(r+w+pad+dpml) # cell size

# %%
ring2_center = mp.Vector3(0,(r+w+r/2+w/2),0)

# %%
cyl1 = mp.Cylinder(radius=r+w, material=mp.Medium(index=n)) # outer circle
cyl2 = mp.Cylinder(radius=r) # punch a hole through circle 1 to make ring
cyl3 = mp.Cylinder(radius=(r/2+w), material=mp.Medium(index=n),center=ring2_center)
cyl4 = mp.Cylinder(radius=r/2, center=ring2_center)

# %%
guide = mp.Block(mp.Vector3(10,w,0),
                     center=mp.Vector3(0,-3.5,0),
                     material=mp.Medium(index=n))
guide2 = mp.Block(mp.Vector3(10, w, 0), center=mp.Vector3(0,2*(r+w)+w-0.2,0), material=mp.Medium(index=n))

# %%
fcen = 0.15
df = 0.1
#src = mp.Source(mp.GaussianSource(fcen, fwidth=df), mp.Ez, mp.Vector3(r+0.1))

# %%
src = mp.Source(mp.ContinuousSource(frequency=0.15),
                     component=mp.Ez,
                     center=mp.Vector3(-4,-3.5,0))

# %%
sim = mp.Simulation(cell_size=mp.Vector3(sxy,sxy), geometry=[cyl1, cyl2, guide, cyl3, cyl4, guide2], sources=[src], resolution=10, boundary_layers=[mp.PML(dpml)])

# %%
#sim.run(mp.at_beginning(mp.output_epsilon), mp.after_sources(mp.Harminv(mp.Ez, mp.Vector3(r+0.1), fcen, df)), until_after_sources=300)
sim.run(until=200)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000290155 s
# Working in 2D dimensions.
# Computational cell is 18.4 x 18.4 x 0 with resolution 10
#      cylinder, center = (0,0,0)
#           radius 3.2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (11.56,11.56,11.56)
#      cylinder, center = (0,0,0)
#           radius 2.2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-3.5,0)
#           size (10,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.56,11.56,11.56)
#      cylinder, center = (0,4.8,0)
#           radius 2.1, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (11.56,11.56,11.56)
#      cylinder, center = (0,4.8,0)
#           radius 1.1, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,7.2,0)
#           size (10,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (11.56,11.56,11.56)
# time for set_epsilon = 0.170229 s
# -----------
# run 0 finished at t = 200.0 (4000 timesteps)

# %%
eps_data = sim.get_array(center=mp.Vector3(), size=mp.Vector3(sxy,sxy), component=mp.Dielectric)
plt.figure()
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()

# %%
ez_data = sim.get_array(center=mp.Vector3(), size=mp.Vector3(sxy,sxy), component=mp.Ez)
plt.figure()
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='magma', alpha=0.90)
plt.axis('off')
plt.show()
